# %% [markdown]
# # 🖊️ Exercice d'analyse exploratoire des données
#
# <img src="https://cdn.pixabay.com/photo/2013/01/27/13/15/flower-76336_960_720.jpg" alt="classification" width="400"/>
#
# #### [Pierre-Loic BAYART](https://www.linkedin.com/in/pierreloicbayart/) - Formation développeur d'applications spécialisation data analyst - Webforce3 - Grenoble Ecole de Management
#
# # ❗ Pensez bien à enregistrer le notebook à la fin
#
# - **Récupérer** le jeu de données des iris dans la bibliothèque Scikit-Learn dans un **dataframe pandas** à partir de la documentation suivante : https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html

# %%
from sklearn.datasets import load_iris
import pandas as pd

# %%
iris = load_iris()

# %%
X = iris.data 
target = iris.target 
names = iris.target_names

# %%
df = pd.DataFrame(X, columns=iris.feature_names)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# - Calculer les **indicateurs** suivants pour toutes les colonnes numériques : **moyenne, médiane, mode, variance, écart type, skewness, kurtosis**

# %%
print("moyenne :",df.mean())
print("   ")
print("medianne :", df.median())
print("   ")
print("mode :", df.mode(0))
print("   ")
print("variance: ", df.var())
print("   ")
print("écart type : ", df.std())
print("   ")
print("skweness : ", df.skew())
print("   ")
print("kurtosis : ", df.kurtosis())
# Out:
# moyenne : sepal length (cm)    5.843333
# sepal width (cm)     3.057333
# petal length (cm)    3.758000
# petal width (cm)     1.199333
# dtype: float64
#
# medianne : sepal length (cm)    5.80
# sepal width (cm)     3.00
# petal length (cm)    4.35
# petal width (cm)     1.30
# dtype: float64
#
# mode :    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.0               3.0                1.4               0.2
# 1                NaN               NaN                1.5               NaN
#
# variance:  sepal length (cm)    0.685694
# sepal width (cm)     0.189979
# petal length (cm)    3.116278
# petal width (cm)     0.581006
# dtype: float64
#
# écart type :  sepal length (cm)    0.828066
# sepal width (cm)     0.435866
# petal length (cm)    1.765298
# petal width (cm)     0.762238
# dtype: float64
#
# skweness :  sepal length (cm)    0.314911
# sepal width (cm)     0.318966
# petal length (cm)   -0.274884
# petal width (cm)    -0.102967
# dtype: float64
#
# kurtosis :  sepal length (cm)   -0.552064
# sepal width (cm)     0.228249
# petal length (cm)   -1.402103
# petal width (cm)    -1.340604
# dtype: float64

# %% [markdown]
# - Calculer ces **mêmes indicateurs** mais cette fois-ci pour **chacune des classes d'iris**

# %%
df['species'] = iris.target
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      species
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 145        2
# 146        2
# 147        2
# 148        2
# 149        2
#
# [150 rows x 5 columns]

# %%
df['species'] = df['species'].replace(to_replace= [0, 1, 2], value = ['setosa', 'versicolor', 'virginica'])
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 5 columns]

# %%
grp = df.groupby('species')

print("moyenne :", grp.mean())
print("   ")
print("medianne :", grp.median())
print("   ")
print("mode :", grp.agg(pd.Series.mode))
print("   ")
print("variance: ", grp.var())
print("   ")
print("écart type : ", grp.std())
print("   ")
print("skweness : ", grp.skew())
print("   ")
print("kurtosis : ", grp.agg(pd.DataFrame.kurt))
# Out:
# moyenne :             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# setosa                  5.006             3.428              1.462
# versicolor              5.936             2.770              4.260
# virginica               6.588             2.974              5.552
#
#             petal width (cm)
# species
# setosa                 0.246
# versicolor             1.326
# virginica              2.026
#
# medianne :             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# setosa                    5.0               3.4               1.50
# versicolor                5.9               2.8               4.35
# virginica                 6.5               3.0               5.55
#
#             petal width (cm)
# species
# setosa                   0.2
# versicolor               1.3
# virginica                2.0
#
# mode :             sepal width (cm)  petal width (cm)
# species
# setosa                   3.4               0.2
# versicolor               3.0               1.3
# virginica                3.0               1.8
#
# variance:              sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# setosa               0.124249          0.143690           0.030159
# versicolor           0.266433          0.098469           0.220816
# virginica            0.404343          0.104004           0.304588
#
#             petal width (cm)
# species
# setosa              0.011106
# versicolor          0.039106
# virginica           0.075433
#
# écart type :              sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# setosa               0.352490          0.379064           0.173664
# versicolor           0.516171          0.313798           0.469911
# virginica            0.635880          0.322497           0.551895
#
#             petal width (cm)
# species
# setosa              0.105386
# versicolor          0.197753
# virginica           0.274650
#
# skweness :              sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# setosa               0.120087          0.041167           0.106394
# versicolor           0.105378         -0.362845          -0.606508
# virginica            0.118015          0.365949           0.549445
#
#             petal width (cm)
# species
# setosa              1.253861
# versicolor         -0.031180
# virginica          -0.129477
#
# kurtosis :              sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# setosa              -0.252689          0.954703           1.021576
# versicolor          -0.533010         -0.366237           0.047903
# virginica            0.032904          0.706071          -0.153779
#
#             petal width (cm)
# species
# setosa              1.719130
# versicolor         -0.410059
# virginica          -0.602264
# /tmp/ipykernel_1696/3059074769.py:7: FutureWarning: ['sepal length (cm)', 'petal length (cm)'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   print("mode :", grp.agg(pd.Series.mode))

# %% [markdown]
# - A l'aide des bibliothèques **Seaborn** et **Plotly**, **analyser graphiquement** le **lien** entre la **classe d'Iris** et la **longueur des pétales**

# %%
import seaborn as sns

# %%
sns.boxplot(data=df, x=df["species"],y=df['petal length (cm)'])
# Out:
# <AxesSubplot: xlabel='species', ylabel='petal length (cm)'>

# %%
sns.stripplot(data=df, x=df["species"],y=df['petal length (cm)'])
# Out:
# <AxesSubplot: xlabel='species', ylabel='petal length (cm)'>

# %% [markdown]
# Source images d'illustration : Image par Manfred Nimbs de Pixabay
