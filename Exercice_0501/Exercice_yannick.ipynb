# %% [markdown]
# # 🖊️ Exercice d'analyse exploratoire des données
#
# <img src="https://cdn.pixabay.com/photo/2013/01/27/13/15/flower-76336_960_720.jpg" alt="classification" width="400"/>
#
# #### [Pierre-Loic BAYART](https://www.linkedin.com/in/pierreloicbayart/) - Formation développeur d'applications spécialisation data analyst - Webforce3 - Grenoble Ecole de Management
#
# # ❗ Pensez bien à enregistrer le notebook à la fin
#
# - **Récupérer** le jeu de données des iris dans la bibliothèque Scikit-Learn dans un **dataframe pandas** à partir de la documentation suivante : https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter("ignore")

# %%
iris = sns.load_dataset("iris")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# - Calculer les **indicateurs** suivants pour toutes les colonnes numériques : **moyenne, médiane, mode, variance, écart type, skewness, kurtosis**

# %%
iris.describe(include = "all")
# Out:
#         sepal_length  sepal_width  petal_length  petal_width species
# count     150.000000   150.000000    150.000000   150.000000     150
# unique           NaN          NaN           NaN          NaN       3
# top              NaN          NaN           NaN          NaN  setosa
# freq             NaN          NaN           NaN          NaN      50
# mean        5.843333     3.057333      3.758000     1.199333     NaN
# std         0.828066     0.435866      1.765298     0.762238     NaN
# min         4.300000     2.000000      1.000000     0.100000     NaN
# 25%         5.100000     2.800000      1.600000     0.300000     NaN
# 50%         5.800000     3.000000      4.350000     1.300000     NaN
# 75%         6.400000     3.300000      5.100000     1.800000     NaN
# max         7.900000     4.400000      6.900000     2.500000     NaN

# %%
iris.mean()
# Out:
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64

# %%
iris.median()
# Out:
# sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# dtype: float64

# %%
iris.mode()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species
# 0           5.0          3.0           1.4          0.2      setosa
# 1           NaN          NaN           1.5          NaN  versicolor
# 2           NaN          NaN           NaN          NaN   virginica

# %%
iris.var()
# Out:
# sepal_length    0.685694
# sepal_width     0.189979
# petal_length    3.116278
# petal_width     0.581006
# dtype: float64

# %%
iris.std()
# Out:
# sepal_length    0.828066
# sepal_width     0.435866
# petal_length    1.765298
# petal_width     0.762238
# dtype: float64

# %%
iris.kurtosis()
# Out:
# sepal_length   -0.552064
# sepal_width     0.228249
# petal_length   -1.402103
# petal_width    -1.340604
# dtype: float64

# %%
iris.skew()
# Out:
# sepal_length    0.314911
# sepal_width     0.318966
# petal_length   -0.274884
# petal_width    -0.102967
# dtype: float64

# %% [markdown]
# - Calculer ces **mêmes indicateurs** mais cette fois-ci pour **chacune des classes d'iris**

# %%
setosa = iris[iris.species == "setosa"]
setosa.describe(include = "all")
# Out:
#         sepal_length  sepal_width  petal_length  petal_width species
# count       50.00000    50.000000     50.000000    50.000000      50
# unique           NaN          NaN           NaN          NaN       1
# top              NaN          NaN           NaN          NaN  setosa
# freq             NaN          NaN           NaN          NaN      50
# mean         5.00600     3.428000      1.462000     0.246000     NaN
# std          0.35249     0.379064      0.173664     0.105386     NaN
# min          4.30000     2.300000      1.000000     0.100000     NaN
# 25%          4.80000     3.200000      1.400000     0.200000     NaN
# 50%          5.00000     3.400000      1.500000     0.200000     NaN
# 75%          5.20000     3.675000      1.575000     0.300000     NaN
# max          5.80000     4.400000      1.900000     0.600000     NaN

# %%
print("moyenne" , setosa.mean() ,":\n",":\n","variance", setosa.var() ,":\n",":\n","mode" ,setosa.mode() ,":\n",":\n", "mediane",setosa.median() ,":\n",":\n","ecart type", setosa.std() ,":\n",":\n", "kurtosis" ,setosa.kurtosis() ,":\n", ":\n","skewness", setosa.skew())
# Out:
# moyenne sepal_length    5.006
# sepal_width     3.428
# petal_length    1.462
# petal_width     0.246
# dtype: float64 :
#  :
#  variance sepal_length    0.124249
# sepal_width     0.143690
# petal_length    0.030159
# petal_width     0.011106
# dtype: float64 :
#  :
#  mode    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.0          3.4           1.4          0.2  setosa
# 1           5.1          NaN           1.5          NaN     NaN :
#  :
#  mediane sepal_length    5.0
# sepal_width     3.4
# petal_length    1.5
# petal_width     0.2
# dtype: float64 :
#  :
#  ecart type sepal_length    0.352490
# sepal_width     0.379064
# petal_length    0.173664
# petal_width     0.105386
# dtype: float64 :
#  :
#  kurtosis sepal_length   -0.252689
# sepal_width     0.954703
# petal_length    1.021576
# petal_width     1.719130
# dtype: float64 :
#  :
#  skewness sepal_length    0.120087
# sepal_width     0.041167
# petal_length    0.106394
# petal_width     1.253861
# dtype: float64

# %%
versicolor = iris[iris.species == "versicolor"]
versicolor.describe(include = "all")
# Out:
#         sepal_length  sepal_width  petal_length  petal_width     species
# count      50.000000    50.000000     50.000000    50.000000          50
# unique           NaN          NaN           NaN          NaN           1
# top              NaN          NaN           NaN          NaN  versicolor
# freq             NaN          NaN           NaN          NaN          50
# mean        5.936000     2.770000      4.260000     1.326000         NaN
# std         0.516171     0.313798      0.469911     0.197753         NaN
# min         4.900000     2.000000      3.000000     1.000000         NaN
# 25%         5.600000     2.525000      4.000000     1.200000         NaN
# 50%         5.900000     2.800000      4.350000     1.300000         NaN
# 75%         6.300000     3.000000      4.600000     1.500000         NaN
# max         7.000000     3.400000      5.100000     1.800000         NaN

# %%
print("moyenne" , versicolor.mean() ,":\n",":\n","variance", versicolor.var() ,":\n",":\n","mode" ,versicolor.mode() ,":\n",":\n", "mediane",versicolor.median() ,":\n",":\n","ecart type", versicolor.std() ,":\n",":\n", "kurtosis" ,versicolor.kurtosis() ,":\n", ":\n","skewness", versicolor.skew())
# Out:
# moyenne sepal_length    5.936
# sepal_width     2.770
# petal_length    4.260
# petal_width     1.326
# dtype: float64 :
#  :
#  variance sepal_length    0.266433
# sepal_width     0.098469
# petal_length    0.220816
# petal_width     0.039106
# dtype: float64 :
#  :
#  mode    sepal_length  sepal_width  petal_length  petal_width     species
# 0           5.5          3.0           4.5          1.3  versicolor
# 1           5.6          NaN           NaN          NaN         NaN
# 2           5.7          NaN           NaN          NaN         NaN :
#  :
#  mediane sepal_length    5.90
# sepal_width     2.80
# petal_length    4.35
# petal_width     1.30
# dtype: float64 :
#  :
#  ecart type sepal_length    0.516171
# sepal_width     0.313798
# petal_length    0.469911
# petal_width     0.197753
# dtype: float64 :
#  :
#  kurtosis sepal_length   -0.533010
# sepal_width    -0.366237
# petal_length    0.047903
# petal_width    -0.410059
# dtype: float64 :
#  :
#  skewness sepal_length    0.105378
# sepal_width    -0.362845
# petal_length   -0.606508
# petal_width    -0.031180
# dtype: float64

# %%
virginica = iris[iris.species == "virginica"]
virginica.describe(include = "all")
# Out:
#         sepal_length  sepal_width  petal_length  petal_width    species
# count       50.00000    50.000000     50.000000     50.00000         50
# unique           NaN          NaN           NaN          NaN          1
# top              NaN          NaN           NaN          NaN  virginica
# freq             NaN          NaN           NaN          NaN         50
# mean         6.58800     2.974000      5.552000      2.02600        NaN
# std          0.63588     0.322497      0.551895      0.27465        NaN
# min          4.90000     2.200000      4.500000      1.40000        NaN
# 25%          6.22500     2.800000      5.100000      1.80000        NaN
# 50%          6.50000     3.000000      5.550000      2.00000        NaN
# 75%          6.90000     3.175000      5.875000      2.30000        NaN
# max          7.90000     3.800000      6.900000      2.50000        NaN

# %%
print("moyenne" , virginica.mean() ,":\n",":\n","variance", virginica.var() ,":\n",":\n","mode" ,virginica.mode() ,":\n",":\n", "mediane",virginica.median() ,":\n",":\n","ecart type", virginica.std() ,":\n",":\n", "kurtosis" ,virginica.kurtosis() ,":\n", ":\n","skewness", virginica.skew())
# Out:
# moyenne sepal_length    6.588
# sepal_width     2.974
# petal_length    5.552
# petal_width     2.026
# dtype: float64 :
#  :
#  variance sepal_length    0.404343
# sepal_width     0.104004
# petal_length    0.304588
# petal_width     0.075433
# dtype: float64 :
#  :
#  mode    sepal_length  sepal_width  petal_length  petal_width    species
# 0           6.3          3.0           5.1          1.8  virginica :
#  :
#  mediane sepal_length    6.50
# sepal_width     3.00
# petal_length    5.55
# petal_width     2.00
# dtype: float64 :
#  :
#  ecart type sepal_length    0.635880
# sepal_width     0.322497
# petal_length    0.551895
# petal_width     0.274650
# dtype: float64 :
#  :
#  kurtosis sepal_length    0.032904
# sepal_width     0.706071
# petal_length   -0.153779
# petal_width    -0.602264
# dtype: float64 :
#  :
#  skewness sepal_length    0.118015
# sepal_width     0.365949
# petal_length    0.549445
# petal_width    -0.129477
# dtype: float64

# %% [markdown]
# - A l'aide des bibliothèques **Seaborn** et **Plotly**, **analyser graphiquement** le **lien** entre la **classe d'Iris** et la **longueur des pétales**

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df=iris[["petal_length","species"]]
df
# Out:
#      petal_length    species
# 0             1.4     setosa
# 1             1.4     setosa
# 2             1.3     setosa
# 3             1.5     setosa
# 4             1.4     setosa
# ..            ...        ...
# 145           5.2  virginica
# 146           5.0  virginica
# 147           5.2  virginica
# 148           5.4  virginica
# 149           5.1  virginica
#
# [150 rows x 2 columns]

# %%
df.plot(kind='scatter', title='classes d\'iris en finction des longueur de pétales', x='species', y='petal_length')
plt.show()

# %% [markdown]
# Source images d'illustration : Image par Manfred Nimbs de Pixabay
