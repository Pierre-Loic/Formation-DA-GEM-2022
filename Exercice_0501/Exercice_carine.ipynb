# %% [markdown]
# # 🖊️ Exercice d'analyse exploratoire des données
#
# <img src="https://cdn.pixabay.com/photo/2013/01/27/13/15/flower-76336_960_720.jpg" alt="classification" width="400"/>
#
# #### [Pierre-Loic BAYART](https://www.linkedin.com/in/pierreloicbayart/) - Formation développeur d'applications spécialisation data analyst - Webforce3 - Grenoble Ecole de Management
#
# # ❗ Pensez bien à enregistrer le notebook à la fin
#
# - **Récupérer** le jeu de données des iris dans la bibliothèque Scikit-Learn dans un **dataframe pandas** à partir de la documentation suivante : https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# - Calculer les **indicateurs** suivants pour toutes les colonnes numériques : **moyenne, médiane, mode, variance, écart type, skewness, kurtosis**

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print('mode  : ') 
print(iris.mode())
print()
print('moyenne : ') 
print(iris.mean())
print()
print('Ecart Type : ')  
print(iris.std())
print()
print('variance : ')  
print(iris.var())
print()
print('Médiane  :')
print(iris.median())
print()
print('skewness : ')  
print(iris.skew())
print()
print('kurtosis : ')  
print(iris.kurtosis())
print('*****************************')
# Out:
# mode  :
#    sepal_length  sepal_width  petal_length  petal_width     species
# 0           5.0          3.0           1.4          0.2      setosa
# 1           NaN          NaN           1.5          NaN  versicolor
# 2           NaN          NaN           NaN          NaN   virginica
#
# moyenne :
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64
#
# Ecart Type :
# sepal_length    0.828066
# sepal_width     0.435866
# petal_length    1.765298
# petal_width     0.762238
# dtype: float64
#
# variance :
# sepal_length    0.685694
# sepal_width     0.189979
# petal_length    3.116278
# petal_width     0.581006
# dtype: float64
#
# Médiane  :
# sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# dtype: float64
#
# skewness :
# sepal_length    0.314911
# sepal_width     0.318966
# petal_length   -0.274884
# petal_width    -0.102967
# dtype: float64
#
# kurtosis :
# sepal_length   -0.552064
# sepal_width     0.228249
# petal_length   -1.402103
# petal_width    -1.340604
# dtype: float64
# *****************************
# /tmp/ipykernel_1732/3972479301.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(iris.mean())
# /tmp/ipykernel_1732/3972479301.py:8: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(iris.std())
# /tmp/ipykernel_1732/3972479301.py:11: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(iris.var())
# /tmp/ipykernel_1732/3972479301.py:14: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(iris.median())
# /tmp/ipykernel_1732/3972479301.py:17: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(iris.skew())
# /tmp/ipykernel_1732/3972479301.py:20: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(iris.kurtosis())

# %% [markdown]
# - Calculer ces **mêmes indicateurs** mais cette fois-ci pour **chacune des classes d'iris**

# %%
print('moyenne : ') 
print(iris.groupby("species").mean())
print()
print('Ecart Type : ')  
print(iris.groupby("species").std())
print()
print('variance : ')  
print(iris.groupby("species").var())
print()
print('Médiane  :')
print(iris.groupby("species").median())
print()
print('skewness : ')  
print(iris.groupby("species").skew())

print('*****************************')
# Out:
# moyenne :
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026
#
# Ecart Type :
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa          0.352490     0.379064      0.173664     0.105386
# versicolor      0.516171     0.313798      0.469911     0.197753
# virginica       0.635880     0.322497      0.551895     0.274650
#
# variance :
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa          0.124249     0.143690      0.030159     0.011106
# versicolor      0.266433     0.098469      0.220816     0.039106
# virginica       0.404343     0.104004      0.304588     0.075433
#
# Médiane  :
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               5.0          3.4          1.50          0.2
# versicolor           5.9          2.8          4.35          1.3
# virginica            6.5          3.0          5.55          2.0
#
# skewness :
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa          0.120087     0.041167      0.106394     1.253861
# versicolor      0.105378    -0.362845     -0.606508    -0.031180
# virginica       0.118015     0.365949      0.549445    -0.129477
# *****************************

# %% [markdown]
# - A l'aide des bibliothèques **Seaborn** et **Plotly**, **analyser graphiquement** le **lien** entre la **classe d'Iris** et la **longueur des pétales**

# %%
X = iris.petal_length
y = iris.species
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: petal_length, Length: 150, dtype: float64

# %%
# sns.lineplot( iris["petal_length"], iris['species'])
sns.lineplot( iris["petal_length"], iris['sepal_length'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 # sns.lineplot( iris["petal_length"], iris['species'])
# ----> 2 sns.lineplot( iris["petal_length"], iris['sepal_length'])
#
# TypeError: lineplot() takes from 0 to 1 positional arguments but 2 were given

# %%
sns.pairplot(iris)
plt.show()

# %%
iris.hist()
iris.plot.kde()
plt.show()

# %% [markdown]
# Source images d'illustration : Image par Manfred Nimbs de Pixabay
